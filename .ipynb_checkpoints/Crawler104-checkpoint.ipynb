# %%
import requests as r
import sqlite3
import lxml
from bs4 import BeautifulSoup
import math
import time
import pprint
import threading

# %%
# index
index = "https://www.104.com.tw"

# job page list href (page1)
# https://www.104.com.tw/jobbank/joblist/auto_joblist.cfm?auto=1&jobsource=n104bank1&ro=0&jobcat=2007000000&order=2&asc=0&page=1&psl=N_A

# job href selector
# soup.select('div.jobname_summary')[0].select('a')[0]['href']

# %%
# create table & drop table
with sqlite3.connect('job.sqlite') as conn:
    c = conn.cursor()
    try:
        c.execute('drop table job104')
        print('drop table job104')
    except:
        c.execute('''
            CREATE TABLE job104(
              jobID INTEGER PRIMARY KEY AUTOINCREMENT,
              title TEXT NOT NULL,
              href TEXT NOT NULL,
              times INTEGER,
              info TEXT)''')
        print('create table job104')
# Out:
# create table job104

# %%
# number of total job 
# there are 20 job hrefs in each page
# so, if 19974 jobs / 20 ---> 997.35 pages
# but we could only get into page 150
def getPage104(href):
    res = r.get(href)
    totalPages = int(BeautifulSoup(res.text, 'lxml').select('form#jobform')[0].select('ul')[0].select('li')[0].text.split('筆')[0][1:].strip())
    res.close()
    totalPages = 150 if math.ceil(totalPages / 20)  > 150 else math.ceil(totalPages / 20) 
    return totalPages

# %%
# sqlite insert&update -> job104
def insert_href(title, href):
    try:
        with sqlite3.connect('job.sqlite') as conn:

            # Query histry, whether we have insert it before...
            c = conn.cursor()
            qryString = "SELECT href FROM job104 where href=:href"
            c.execute(qryString, {'href' : href})
            # if there are nothing like href
            if len(c.fetchall()) == 0:
                # insert new one
                insert_string = "INSERT INTO job104 (title, href, times) VALUES (?, ?, 1)"
                c.execute(insert_string, (title, href))
            else:
                update_string = "UPDATE job104 SET times = times + 1 WHERE href = ?"
                c.execute(update_string, (href,))

    except ConnectionError as e:
        print(e)
        print(href)

# %%
getPage104('https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001010%2C2007001012&order=3&asc=0&page=1')
# Out:
# 92

# %%
# main program
totalPages = getPage104('https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007002002&order=2&asc=0&page=1')
print('totalPages: ' + str(totalPages))
for page in range(1, totalPages + 1):
# for page in range(1, 86):
# all 
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007000000&order=3&asc=0&page={}".format(page)
# 軟體專案主管
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001001&order=3&asc=0&page={}".format(page)
# 通訊軟體工程師
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001003&order=3&asc=0&page={}".format(page)
# 韌體設計工程師
#    href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001005&order=3&asc=0&page={}".format(page)
# 電腦系統分析師
#    href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001007&order=3&asc=0&page={}".format(page)
# 其他資訊專業人員、BIOS工程師、電子商務技術主管    
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001009%2C2007001011%2C2007001002&order=3&asc=0&page={}".format(page)
# 資訊助理人員、演算法開發工程師
#    href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001010%2C2007001012&order=3&asc=0&page={}".format(page)
# 電玩程式設計師
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001008&order=2&asc=0&page={}".format(page)
# Internet程式設計師
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001006&order=3&asc=0&page={}".format(page)
# 軟體設計工程師 (經歷 多→少)
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=3&asc=0&page={}".format(page)
# 軟體設計工程師 (經歷 少→多)
#    href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=3&asc=1&page={}".format(page)
# 軟體設計工程師 日期 新→舊   
#    href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=2&asc=0&page={}".format(page)
# 軟體設計工程師 日期 舊→新
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=2&asc=1&page={}".format(page)
# 軟體設計工程師 地區
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=5&asc=0&page={}".format(page)
# 軟體設計工程師 相關性
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=1&asc=0&page={}".format(page)
# 軟體設計工程師 學歷 高→低
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=4&asc=0&page={}".format(page)
# 軟體設計工程師 學歷 低→高
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=4&asc=1&page={}".format(page)
# 軟體設計工程師 應徵人數 高→低
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=7&asc=0&page={}".format(page)
# 軟體設計工程師 應徵人數 低→高
#    href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=7&asc=1&page={}".format(page)
# 軟體設計工程師 待遇 高→低
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=6&asc=1&page={}".format(page)
# 軟體設計工程師 待遇 低→高
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001004&order=6&asc=0&page={}".format(page)
# Internet程式設計師 日期 舊→新    
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001006&order=2&asc=1&page={}".format(page)
# Internet程式設計師 日期 新→舊    
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007001006&order=2&asc=0&page={}".format(page)
# MIS╱網管主管、網路管理工程師、資訊設備管制人員
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007002001%2C2007002005%2C2007002007&order=2&asc=0&page={}".format(page)
# MIS程式設計師
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007002003&order=2&asc=0&page={}".format(page)
# MES工程師、系統維護╱操作人員、網路安全分析師
#     href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007002004%2C2007002006%2C2007002008&order=2&asc=0&page={}".format(page)
# 資料庫管理人員
    href = "https://www.104.com.tw/jobbank/joblist/joblist.cfm?jobsource=n104bank1&ro=0&jobcat=2007002002&order=2&asc=0&page={}".format(page)
    
    soup = BeautifulSoup(r.get(href).text, 'lxml')
    jidSoup = soup.select('div.job_name')
    totalJid = len(jidSoup)
    if page % 10 == 0:
        print(str(page) + ' / ' + str(totalPages))
    for jid in range(0, totalJid):
        title = soup.select('div.job_name')[jid].text.strip()
        href = "https://www.104.com.tw" + jidSoup[jid].select('a')[0]['href']
        insert_href(title, href)
    
    time.sleep(1)
    
print('done!!')
# Out:
# totalPages: 65
# 10 / 65
# 20 / 65
# 30 / 65
# 40 / 65
# 50 / 65
# 60 / 65
# done!!

# %%
# Query result program
# 2017/05/08 : 2960 web(exclude repeat)
with sqlite3.connect('job.sqlite') as conn:
    c = conn.cursor()
    pprint.pprint(list(c.execute('select * from job104')))
# Out:
# [(1,
#   '運維主管',
#   'https://www.104.com.tw/job/?jobno=57o0l&jobsource=104_hotorder',
#   1,
#   None),
#  (2,
#   '系統分析師 (月薪80000元以上)',
#   'https://www.104.com.tw/job/?jobno=5gm45&jobsource=104_hotorder',
#   8,
#   None),
#  (3,
#   'DevOps',
#   'https://www.104.com.tw/job/?jobno=4qh2a&jobsource=104_hotorder',
#   13,
#   None),
#  (4,
#   '系統分析師 Solutions Delivery Analyst',
#   'https://www.104.com.tw/job/?jobno=4cwz0&jobsource=104_hotorder',
#   4,
#   None),
#  (5,
#   '約聘系統分析師 Solutions Delivery Analyst (Contractor)',
#   'https://www.104.com.tw/job/?jobno=5g0bc&jobsource=104_hotorder',
#   4,
#   None),
#  (6,
#   '資深後端工程師',
#   'https://www.104.com.tw/job/?jobno=5edsi&jobsource=104_hotorder',
#   16,
#   None),
#  (7,
#   'PHP資深後端工程師 (上班地點台中)',
#   'https://www.104.com.tw/job/?jobno=5f51j&jobsource=104_hotorder',
#   12,
#   None),
#  (8,
#   'Sr. 前端工程師【人才經營部】',
#   'https://www.104.com.tw/job/?jobno=53nwi&jobsource=104_hotorder',
#   6,
#   None),
#  (9,
#   'Software (SW) System Design Director (DTV / STB)',
#   'https://www.104.com.tw/job/?jobno=5g6yc&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (10,
#   '系統開發主管',
#   'https://www.104.com.tw/job/?jobno=5g79t&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (11,
#   'JO- CTO/ 軟體公司',
#   'https://www.104.com.tw/job/?jobno=5gg9d&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (12,
#   '資深保險系統分析師',
#   'https://www.104.com.twhttp://hunter.104.com.tw/104hunter.jsp?trc=104p&jobsource=n104bank1&urlpage=job_description&jobno=9178215',
#   2,
#   None),
#  (13,
#   '【Insurance Company 】 AS400 COBOL Senior System Designer',
#   'https://www.104.com.tw/job/?jobno=5gpqj&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (14,
#   'MC-長安精密廠加工部經理',
#   'https://www.104.com.tw/job/?jobno=5gr7o&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (15,
#   '技術副總監',
#   'https://www.104.com.tw/job/?jobno=5g1v5&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (16,
#   'MIS資訊主管',
#   'https://www.104.com.tw/job/?jobno=5g5ma&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (17,
#   '資訊經理',
#   'https://www.104.com.tw/job/?jobno=5f050&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (18,
#   'Java工程師(醫療業)',
#   'https://www.104.com.tw/job/?jobno=5f5dx&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (19,
#   'C#工程師(醫療業)',
#   'https://www.104.com.tw/job/?jobno=5f5en&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (20,
#   'Pr. Engineer - Bluetooth Audio SW Architect',
#   'https://www.104.com.tw/job/?jobno=5d4mh&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (21,
#   '供應鏈主管 (F02)',
#   'https://www.104.com.tw/job/?jobno=5ggel&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (22,
#   '(Touch) 研發主管',
#   'https://www.104.com.tw/job/?jobno=5gmb2&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (23,
#   'Information System Manager - Taiwan and Hong Kong',
#   'https://www.104.com.tw/job/?jobno=5gmeh&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (24,
#   'ITD-03 IT副理',
#   'https://www.104.com.tw/job/?jobno=5dtem&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (25,
#   'Oracle ERP資深工程師',
#   'https://www.104.com.tw/job/?jobno=5e3w2&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (26,
#   '資訊主管',
#   'https://www.104.com.tw/job/?jobno=5ft6a&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (27,
#   '資深產品開發韌體工程師  Sr. Product Development/ Firmware Engineer',
#   'https://www.104.com.tw/job/?jobno=5fwes&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (28,
#   'MY徵【東南亞】製造業_資訊長CIO_TCL2',
#   'https://www.104.com.tw/job/?jobno=5cblo&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (29,
#   'Sr. Lead Design Engineer (Network Switch) of Server BU',
#   'https://www.104.com.twhttp://hunter.104.com.tw/104hunter.jsp?trc=104p&jobsource=n104bank1&urlpage=job_description&jobno=8986208',
#   6,
#   None),
#  (30,
#   '遊戲開發技術主管',
#   'https://www.104.com.tw/job/?jobno=5cm68&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (31,
#   '韌體設計工程師',
#   'https://www.104.com.tw/job/?jobno=5cqff&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (32,
#   '技術總監 (深圳 / 香港)',
#   'https://www.104.com.tw/job/?jobno=5ex7c&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (33,
#   '[行政]高級系統分析師',
#   'https://www.104.com.tw/job/?jobno=5ekec&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (34,
#   'SW Project Leader',
#   'https://www.104.com.tw/job/?jobno=59jiq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (35,
#   'Senior Infrastructure Specialist(Database, System)',
#   'https://www.104.com.tw/job/?jobno=5b2tc&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (36,
#   'Senior Infrastructure Specialist(Network, Sysem)',
#   'https://www.104.com.tw/job/?jobno=5b3ny&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (37,
#   'CL-行動網路規劃技術經理',
#   'https://www.104.com.tw/job/?jobno=5b99n&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (38,
#   'Backend Team Lead',
#   'https://www.104.com.tw/job/?jobno=5beha&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (39,
#   'Architect/Software Engineering Director',
#   'https://www.104.com.tw/job/?jobno=5dfr9&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (40,
#   'T5R130-SQA Engineer(System Quality Assurance)',
#   'https://www.104.com.tw/job/?jobno=5dg00&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (41,
#   'SSD Platform Firmware Manager',
#   'https://www.104.com.tw/job/?jobno=5dky6&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (42,
#   '大數據-系統分析師',
#   'https://www.104.com.twhttp://hunter.104.com.tw/104hunter.jsp?trc=104p&jobsource=n104bank1&urlpage=job_description&jobno=9033745',
#   2,
#   None),
#  (43,
#   'Staff Engineer - UI Architect (170172)',
#   'https://www.104.com.tw/job/?jobno=5dqba&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (44,
#   'Sr Prin Systems Engr',
#   'https://www.104.com.tw/job/?jobno=5drb8&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (45,
#   'Sr Prin Systems Engr 1',
#   'https://www.104.com.tw/job/?jobno=5drcl&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (46,
#   'E8501 企業雲端整合規劃技術副理',
#   'https://www.104.com.tw/job/?jobno=5bt4g&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (47,
#   '#170016760 - CIB – Technology – Global Branches Service Delivery Associate',
#   'https://www.104.com.tw/job/?jobno=5butm&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (48,
#   'E8521 雲端SAP技術副理',
#   'https://www.104.com.tw/job/?jobno=5an10&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (49,
#   'E8521 雲端系統技術副理',
#   'https://www.104.com.tw/job/?jobno=5an4s&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (50,
#   '系統開發主管',
#   'https://www.104.com.tw/job/?jobno=5aoai&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (51,
#   'IT 主管 (派駐中國)',
#   'https://www.104.com.tw/job/?jobno=57xgy&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (52,
#   '資深系統架構師 Software Engineer / Programmer(台北)',
#   'https://www.104.com.tw/job/?jobno=57xvg&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (53,
#   '資深系統架構師 Software Engineer / Programmer(台中市政府旁)',
#   'https://www.104.com.tw/job/?jobno=57xw3&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (54,
#   'CTO staff- Security product manager',
#   'https://www.104.com.tw/job/?jobno=58a1x&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (55,
#   'IT Director',
#   'https://www.104.com.tw/job/?jobno=58hi7&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (56,
#   'IT營運主管(台南燦坤先端智能研究所)',
#   'https://www.104.com.tw/job/?jobno=55dao&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (57,
#   'Zyxel_軟體研發主管',
#   'https://www.104.com.tw/job/?jobno=55ehj&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (58,
#   '[知名外商買賣]系統導入專案顧問',
#   'https://www.104.com.tw/job/?jobno=55gqm&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (59,
#   '韌體處長',
#   'https://www.104.com.tw/job/?jobno=560kc&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (60,
#   'OSQ Manager',
#   'https://www.104.com.tw/job/?jobno=56f67&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (61,
#   'MIS主任工程師',
#   'https://www.104.com.tw/job/?jobno=51l9y&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (62,
#   '智慧工廠資深顧問',
#   'https://www.104.com.tw/job/?jobno=51nld&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (63,
#   'MIS資深開發人員(FI3110)',
#   'https://www.104.com.tw/job/?jobno=51o4i&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (64,
#   'Principal Engineer, Network Management Systems (P02771)',
#   'https://www.104.com.tw/job/?jobno=51scs&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (65,
#   'After-sales IT Manager',
#   'https://www.104.com.tw/job/?jobno=51w4u&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (66,
#   '【大數據所】巨量資料平台架構師(定期契約)',
#   'https://www.104.com.tw/job/?jobno=51ya9&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (67,
#   'Architect 系統架構師(派駐馬尼拉)薪15~25萬/月',
#   'https://www.104.com.tw/job/?jobno=52kjm&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (68,
#   'Technical Support Manager',
#   'https://www.104.com.tw/job/?jobno=52l5q&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (69,
#   'Outsourcing Project Manager',
#   'https://www.104.com.tw/job/?jobno=52l63&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (70,
#   '產品企劃管理經理',
#   'https://www.104.com.tw/job/?jobno=52s9f&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (71,
#   '高級系統顧問 Senior Application Consultant( Banking project)',
#   'https://www.104.com.tw/job/?jobno=50oy6&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (72,
#   '資訊主管',
#   'https://www.104.com.tw/job/?jobno=518xg&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (73,
#   'IT Director',
#   'https://www.104.com.tw/job/?jobno=59u8p&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (74,
#   '資訊主管',
#   'https://www.104.com.tw/job/?jobno=5a4wp&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (75,
#   'C.顧問類-協理/副總(business strategy and execution)',
#   'https://www.104.com.tw/job/?jobno=5a9ga&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (76,
#   'C.顧問類-協理/副總(operation strategy)',
#   'https://www.104.com.tw/job/?jobno=5a9gm&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (77,
#   'IIoT Software Architect',
#   'https://www.104.com.tw/job/?jobno=54ffj&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (78,
#   'Enterprise Architect',
#   'https://www.104.com.tw/job/?jobno=54jvl&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (79,
#   'IT資訊規劃師',
#   'https://www.104.com.tw/job/?jobno=54qkg&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (80,
#   '台北-IT副主任',
#   'https://www.104.com.tw/job/?jobno=54rux&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (81,
#   'MIS儲備主管',
#   'https://www.104.com.tw/job/?jobno=56odq&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (82,
#   'Technical PM /技術專案經理',
#   'https://www.104.com.tw/job/?jobno=57dq5&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (83,
#   'QA Manager(派駐海外)',
#   'https://www.104.com.tw/job/?jobno=57hta&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (84,
#   'MY【菲律賓】IT_QA Manager_TCL2',
#   'https://www.104.com.tw/job/?jobno=57n9y&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (85,
#   '資深專案經理 - 保險金融解決方案',
#   'https://www.104.com.tw/job/?jobno=575mw&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (86,
#   'IT Senior Engineer',
#   'https://www.104.com.tw/job/?jobno=4wuf2&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (87,
#   '科技應用部門協理',
#   'https://www.104.com.tw/job/?jobno=4wx4m&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (88,
#   '資訊主管',
#   'https://www.104.com.tw/job/?jobno=4x1uq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (89,
#   'SW RD  Team Leader',
#   'https://www.104.com.tw/job/?jobno=4x9ny&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (90,
#   '传感器专家',
#   'https://www.104.com.tw/job/?jobno=4xnjo&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (91,
#   'T5R130-SQA Manager(System Quality Assurance)',
#   'https://www.104.com.tw/job/?jobno=4xw8q&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (92,
#   '【D900-11251】系統整合測試/經理(竹北)',
#   'https://www.104.com.tw/job/?jobno=4t391&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (93,
#   'Operation Manager',
#   'https://www.104.com.tw/job/?jobno=4tdq1&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (94,
#   '[陸資化工企業] 資訊最高主管',
#   'https://www.104.com.tw/job/?jobno=53im1&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (95,
#   'Head of Education_new business (995)',
#   'https://www.104.com.tw/job/?jobno=4w19p&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (96,
#   'Temp System Engineer (6M)',
#   'https://www.104.com.tw/job/?jobno=4vi6f&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (97,
#   '資深工程師(智慧聯網)',
#   'https://www.104.com.tw/job/?jobno=4vh8n&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (98,
#   '(SW) TV Software Project Leader (派駐印度)(須有SW PM經驗10年以上)',
#   'https://www.104.com.tw/job/?jobno=4rc7b&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (99,
#   '美術總監(502 AHY)',
#   'https://www.104.com.tw/job/?jobno=4s6iq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (100,
#   '資訊主管(台中)',
#   'https://www.104.com.tw/job/?jobno=4ylb0&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (101,
#   'Android 軟體工程師',
#   'https://www.104.com.tw/job/?jobno=4ymy2&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (102,
#   '資訊高階主管',
#   'https://www.104.com.tw/job/?jobno=4z64c&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (103,
#   'H2R220-軟體技術副理',
#   'https://www.104.com.tw/job/?jobno=4za5m&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (104,
#   'Digital and Mobile Solution Architect',
#   'https://www.104.com.tw/job/?jobno=4zkmq&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (105,
#   'Mobility Architect',
#   'https://www.104.com.tw/job/?jobno=4zl1v&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (106,
#   'Digital Cloud Strategy Architect',
#   'https://www.104.com.tw/job/?jobno=4zl6b&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (107,
#   '布列德麵包相關企業/軟體應用開發主管(Java)',
#   'https://www.104.com.tw/job/?jobno=4zqdx&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (108,
#   'Digital Cloud Architect',
#   'https://www.104.com.tw/job/?jobno=4ztxf&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (109,
#   '杭州聯合實驗室主任',
#   'https://www.104.com.tw/job/?jobno=4okcq&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (110,
#   '研發類-研發高階主管(VSBG)',
#   'https://www.104.com.tw/job/?jobno=4oyfp&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (111,
#   'Software Architect',
#   'https://www.104.com.tw/job/?jobno=4ujsz&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (112,
#   '資訊主管-行管處',
#   'https://www.104.com.tw/job/?jobno=4uxk6&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (113,
#   '軟體專案經理',
#   'https://www.104.com.tw/job/?jobno=4uyqd&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (114,
#   '系統開發主管',
#   'https://www.104.com.tw/job/?jobno=4mkk4&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (115,
#   '5G 資深軟體系統工程師',
#   'https://www.104.com.tw/job/?jobno=4n89c&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (116,
#   '5G FPGA 工程師主管<內湖/ 新竹>',
#   'https://www.104.com.tw/job/?jobno=4n89h&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (117,
#   '5G Senior FPGA FW Engineer<內湖/ 新竹>',
#   'https://www.104.com.tw/job/?jobno=4n89u&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (118,
#   '資訊主管(山東青島)',
#   'https://www.104.com.tw/job/?jobno=4pyne&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (119,
#   'CL-S/W RD Head (生理應用技術服務)',
#   'https://www.104.com.tw/job/?jobno=4q3jn&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (120,
#   'CL-IT Head (FMCG)',
#   'https://www.104.com.tw/job/?jobno=4qfxx&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (121,
#   'IT Director (835)',
#   'https://www.104.com.tw/job/?jobno=4qj4h&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (122,
#   '5G (資深)軟體系統工程師(內湖/新竹)',
#   'https://www.104.com.tw/job/?jobno=4hkif&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (123,
#   'M053 資訊處 企業資源系統部主管(MIS主管)',
#   'https://www.104.com.tw/job/?jobno=4i2zx&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (124,
#   '【CA】ISP（IQ)研發工程師',
#   'https://www.104.com.tw/job/?jobno=4iafr&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (125,
#   '【CA】智能視頻(IV)分析研發工程師',
#   'https://www.104.com.tw/job/?jobno=4iagk&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (126,
#   'C++ Manager Software Engineering Who Codes',
#   'https://www.104.com.tw/job/?jobno=4hvdv&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (127,
#   '工程主管 (銀髮事業處)',
#   'https://www.104.com.tw/job/?jobno=4el5c&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (128,
#   'G1060017-資訊主管/特助(集團總部)',
#   'https://www.104.com.tw/job/?jobno=4evb4&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (129,
#   '研發經理',
#   'https://www.104.com.tw/job/?jobno=4kqjk&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (130,
#   '5G Digital System Manager<內湖/新竹>',
#   'https://www.104.com.tw/job/?jobno=4ksz8&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (131,
#   '5G Senior DSP Software 工程師主管<內湖/新竹>',
#   'https://www.104.com.tw/job/?jobno=4kt0g&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (132,
#   '資訊系統部: Global Investment Management, Digital Team Application Development, '
#   'Senior Manager, Vice President',
#   'https://www.104.com.tw/job/?jobno=4lkke&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (133,
#   'JAVA Application Development Team Lead (EC)-208KC',
#   'https://www.104.com.tw/job/?jobno=4bnyj&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (134,
#   'IC設計 研發處長',
#   'https://www.104.com.tw/job/?jobno=4cqjo&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (135,
#   'HR810-TM',
#   'https://www.104.com.tw/job/?jobno=4ey0h&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (136,
#   '通信系統管理經(副)理級主管',
#   'https://www.104.com.tw/job/?jobno=43vre&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (137,
#   'M051 資訊技術服務部經理',
#   'https://www.104.com.tw/job/?jobno=445y1&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (138,
#   'Software Engineering Manager / Software Architect',
#   'https://www.104.com.tw/job/?jobno=46n9t&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (139,
#   '軟體開發部主管',
#   'https://www.104.com.tw/job/?jobno=4aam6&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (140,
#   'CITC_Technical Lead for Big Data Technology',
#   'https://www.104.com.tw/job/?jobno=41fdg&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (141,
#   '檢測主管',
#   'https://www.104.com.tw/job/?jobno=3jfvi&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (142,
#   '研究發展類-韌體研發主管',
#   'https://www.104.com.tw/job/?jobno=3m6jz&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (143,
#   'A0404 NB軟體設計經理',
#   'https://www.104.com.tw/job/?jobno=3mt96&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (144,
#   '軟體經理',
#   'https://www.104.com.tw/job/?jobno=3nvad&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (145,
#   '系統管理經理',
#   'https://www.104.com.tw/job/?jobno=3ov9x&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (146,
#   '專案經理-客製系統服務部',
#   'https://www.104.com.tw/job/?jobno=3th0b&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (147,
#   '自動化開發Project Manager(上海)',
#   'https://www.104.com.tw/job/?jobno=3erj2&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (148,
#   '聯強 系統開發主管(亞太第一大資通訊通路集團)',
#   'https://www.104.com.tw/job/?jobno=2lkuq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (149,
#   'Sr. IT Infrastructure Engineer',
#   'https://www.104.com.tw/job/?jobno=38ssl&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (150,
#   'D30000-技術經理',
#   'https://www.104.com.tw/job/?jobno=ofnk&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (151,
#   'Product Manager',
#   'https://www.104.com.tw/job/?jobno=2xco7&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (152,
#   '電子産品軟體工程師/主管',
#   'https://www.104.com.tw/job/?jobno=31c4o&jobsource=n104bank1&hotjob_chr=',
#   10,
#   None),
#  (153,
#   '【接案】公司內部網頁程式開發',
#   'https://www.104.com.twjavascript:void(0)',
#   1852,
#   None),
#  (154,
#   '【DB50-4103】軟體開發經理',
#   'https://www.104.com.tw/job/?jobno=5f6gh&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (155,
#   '【SW】影像處理軟體技術專才(土城)',
#   'https://www.104.com.tw/job/?jobno=5e5is&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (156,
#   '【DB50-11103】專案技術經理',
#   'https://www.104.com.tw/job/?jobno=5eswe&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (157,
#   '【DB50-11103】Android軟體設計/副理',
#   'https://www.104.com.tw/job/?jobno=51t32&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (158,
#   '資訊科技部 副總裁 VP IT Security',
#   'https://www.104.com.tw/job/?jobno=54drk&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (159,
#   'C.顧問類-資深顧問/經理(SAP B1)',
#   'https://www.104.com.tw/job/?jobno=4uju9&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (160,
#   '專案管理師/專案經理',
#   'https://www.104.com.tw/job/?jobno=3ljm2&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (161,
#   'AC-金融業 MIS經理',
#   'https://www.104.com.tw/job/?jobno=5gfyh&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (162,
#   'MIS專案主管',
#   'https://www.104.com.tw/job/?jobno=5gnqw&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (163,
#   '軟體研發主管',
#   'https://www.104.com.twhttp://hunter.104.com.tw/104hunter.jsp?trc=104p&jobsource=n104bank1&urlpage=job_description&jobno=9179081',
#   8,
#   None),
#  (164,
#   'Architect企業/應用架構師(產險公司)-208KC',
#   'https://www.104.com.tw/job/?jobno=5f8vn&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (165,
#   'Product Director',
#   'https://www.104.com.tw/job/?jobno=5f9ao&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (166,
#   'Android  Platform軟體開發經理',
#   'https://www.104.com.tw/job/?jobno=5fbe8&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (167,
#   'Failure Analyst 3',
#   'https://www.104.com.tw/job/?jobno=5fhxq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (168,
#   'IT 經理 (上海)',
#   'https://www.104.com.tw/job/?jobno=5fxnl&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (169,
#   '軟(韌)體研發工程師',
#   'https://www.104.com.tw/job/?jobno=5fzfk&jobsource=n104bank1&hotjob_chr=',
#   9,
#   None),
#  (170,
#   'Java資深系統工程師(二)(金融保險業專案委外)',
#   'https://www.104.com.tw/job/?jobno=5g2yt&jobsource=n104bank1&hotjob_chr=',
#   12,
#   None),
#  (171,
#   'RD leader',
#   'https://www.104.com.tw/job/?jobno=5eyon&jobsource=n104bank1&hotjob_chr=',
#   9,
#   None),
#  (172,
#   '【DB50-04101】軟體產品管理經理',
#   'https://www.104.com.tw/job/?jobno=5f6g9&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (173,
#   '【DB50-04102】產品管理主任工程師',
#   'https://www.104.com.tw/job/?jobno=5f6gb&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (174,
#   '系統架構師/Solution Architect (160002)',
#   'https://www.104.com.tw/job/?jobno=5f6il&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (175,
#   'IT資深專員/主管',
#   'https://www.104.com.tw/job/?jobno=5d1o5&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (176,
#   '無線產品軟體研發主管',
#   'https://www.104.com.tw/job/?jobno=5d85n&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (177,
#   '資訊工程師(南崁)',
#   'https://www.104.com.tw/job/?jobno=5dbcz&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (178,
#   'Software Development Manager',
#   'https://www.104.com.tw/job/?jobno=5e89o&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (179,
#   '【上海封測廠】IT Infra經理',
#   'https://www.104.com.tw/job/?jobno=5eci1&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (180,
#   'Sr. Application Engineer/Technical lead',
#   'https://www.104.com.twhttp://hunter.104.com.tw/104hunter.jsp?trc=104p&jobsource=n104bank1&urlpage=job_description&jobno=9074922',
#   4,
#   None),
#  (181,
#   'MTS Firmware Engineer (BIOS Engineer)-Server',
#   'https://www.104.com.tw/job/?jobno=5gggd&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (182,
#   'Sr. Software Engineer (Linux/Android BSP)',
#   'https://www.104.com.twhttp://hunter.104.com.tw/104hunter.jsp?trc=104p&jobsource=n104bank1&urlpage=job_description&jobno=9168954',
#   6,
#   None),
#  (183,
#   '總務資訊部主管(理級)',
#   'https://www.104.com.tw/job/?jobno=5gj18&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (184,
#   'SAP Specialist/Developer - Focus on Process Integration',
#   'https://www.104.com.tw/job/?jobno=5gj1y&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (185,
#   '1002847 Systems Software Architect',
#   'https://www.104.com.tw/job/?jobno=5gjwp&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (186,
#   '1002842 UEFI BIOS Development Lead Engineer',
#   'https://www.104.com.tw/job/?jobno=5gjwt&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (187,
#   '運維主管',
#   'https://www.104.com.twhttp://hunter.104.com.tw/104hunter.jsp?trc=104p&jobsource=n104bank1&urlpage=job_description&jobno=9173543',
#   2,
#   None),
#  (188,
#   'JAVA系統架構師(金融保險業專案委外)',
#   'https://www.104.com.tw/job/?jobno=5e1zh&jobsource=n104bank1&hotjob_chr=',
#   10,
#   None),
#  (189,
#   '軟體研發主管',
#   'https://www.104.com.tw/job/?jobno=5e3bf&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (190,
#   '竹科一廠-自動化整合處級主管',
#   'https://www.104.com.tw/job/?jobno=5e3ke&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (191,
#   '雲端系統主管',
#   'https://www.104.com.tw/job/?jobno=5e58i&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (192,
#   'Staff Software Engineer, Java (170337)',
#   'https://www.104.com.tw/job/?jobno=5folz&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (193,
#   'Team Lead-IT Service Support',
#   'https://www.104.com.tw/job/?jobno=5ca8q&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (194,
#   '《天下雜誌群》網管主管',
#   'https://www.104.com.tw/job/?jobno=5cobe&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (195,
#   'I132 高階資訊部門主管',
#   'https://www.104.com.tw/job/?jobno=5enal&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (196,
#   'Technical Manager (台北)',
#   'https://www.104.com.tw/job/?jobno=58uth&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (197,
#   '創新技術研究室 資深韌體工程師',
#   'https://www.104.com.tw/job/?jobno=594hb&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (198,
#   '【IT】自動化軟體專案主管 (MCS/AMHS)',
#   'https://www.104.com.tw/job/?jobno=598vq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (199,
#   '系統規劃經理(公用系統-技術支援處)',
#   'https://www.104.com.tw/job/?jobno=59hig&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (200,
#   '資訊主管',
#   'https://www.104.com.tw/job/?jobno=5bdob&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (201,
#   'Principal /Lead Software Engineer',
#   'https://www.104.com.tw/job/?jobno=5dfr2&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (202,
#   'SW Development Manager ( TW04544-046 863)',
#   'https://www.104.com.tw/job/?jobno=5dhlt&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (203,
#   'Cloud System Director 雲端系統開發總監',
#   'https://www.104.com.tw/job/?jobno=5diyc&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (204,
#   '出版業雲端學院JAVA網站開發程式設計師',
#   'https://www.104.com.tw/job/?jobno=5dkrl&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (205,
#   '軟體主任程師',
#   'https://www.104.com.tw/job/?jobno=5bsug&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (206,
#   'Senior Web Applications Developer',
#   'https://www.104.com.tw/job/?jobno=5bw4h&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (207,
#   '《總公司》系統發展分析師',
#   'https://www.104.com.tw/job/?jobno=5c7y6&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (208,
#   'Sr.System Designer 專案副理',
#   'https://www.104.com.tw/job/?jobno=5ao4r&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (209,
#   'Sr.System Designer 專案副理',
#   'https://www.104.com.tw/job/?jobno=5ao5q&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (210,
#   '資訊部經理【宜蘭力麗威斯汀The Westin Yilan Resort】',
#   'https://www.104.com.tw/job/?jobno=5atas&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (211,
#   '4G 網通軟軔體工程師',
#   'https://www.104.com.tw/job/?jobno=58epb&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (212,
#   'MIS主管',
#   'https://www.104.com.tw/job/?jobno=55ces&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (213,
#   '系統分析師(大雅)',
#   'https://www.104.com.tw/job/?jobno=55e5f&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (214,
#   '1050134 流程研發處 專案管理師',
#   'https://www.104.com.tw/job/?jobno=51vv7&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (215,
#   'SSD Firmware Manager',
#   'https://www.104.com.tw/job/?jobno=4zw52&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (216,
#   'MIS經理/副理',
#   'https://www.104.com.tw/job/?jobno=504wd&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (217,
#   '軟體研發主管',
#   'https://www.104.com.tw/job/?jobno=50jdd&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (218,
#   'C.顧問類-專案經理(資訊系統導入)',
#   'https://www.104.com.tw/job/?jobno=59p2n&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (219,
#   '1606 IC驗證主管',
#   'https://www.104.com.tw/job/?jobno=59svq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (220,
#   'MIS工程主管',
#   'https://www.104.com.tw/job/?jobno=59zhz&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (221,
#   '軟體工程主管',
#   'https://www.104.com.tw/job/?jobno=5473j&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (222,
#   '研發主管',
#   'https://www.104.com.tw/job/?jobno=548l9&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (223,
#   '演算法軟體工程師（C#）',
#   'https://www.104.com.tw/job/?jobno=54ud2&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (224,
#   '(內科遊戲公司) APP研發經理 (D78)',
#   'https://www.104.com.tw/job/?jobno=54zcu&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (225,
#   'ISP 影像演算顧問',
#   'https://www.104.com.tw/job/?jobno=56mvp&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (226,
#   '【DB40-11141】Router軟體設計主管(竹北)',
#   'https://www.104.com.tw/job/?jobno=56o8t&jobsource=n104bank1&hotjob_chr=',
#   9,
#   None),
#  (227,
#   '研發類-MIS Head(Core)',
#   'https://www.104.com.tw/job/?jobno=57bgk&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (228,
#   '701: Solution Architect',
#   'https://www.104.com.tw/job/?jobno=57d5g&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (229,
#   '361: Sr. Project Manager',
#   'https://www.104.com.tw/job/?jobno=57mif&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (230,
#   '運維主管',
#   'https://www.104.com.tw/job/?jobno=57o0l&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (231,
#   '資訊服務處 精實生產主管 (東莞)',
#   'https://www.104.com.tw/job/?jobno=57ofa&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (232,
#   '自動化主管 (東莞/昆山)',
#   'https://www.104.com.tw/job/?jobno=57ofn&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (233,
#   'TA3810 Web 應用系統開發工程師',
#   'https://www.104.com.tw/job/?jobno=4x29a&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (234,
#   'System Architect',
#   'https://www.104.com.tw/job/?jobno=4x9ls&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (235,
#   '工程師-研六部(二課)',
#   'https://www.104.com.tw/job/?jobno=4xr9b&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (236,
#   'IT System Team Lead',
#   'https://www.104.com.tw/job/?jobno=4y0eh&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (237,
#   'Embedded system 資深韌體開發工程師',
#   'https://www.104.com.tw/job/?jobno=4y4y0&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (238,
#   '資深軟體工程師',
#   'https://www.104.com.tw/job/?jobno=4t2df&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (239,
#   '總監(醫療系統部)',
#   'https://www.104.com.tw/job/?jobno=52v7u&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (240,
#   'Senior Applications Engineer- Bluetooth Software',
#   'https://www.104.com.tw/job/?jobno=53vv4&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (241,
#   'Software Developer Manager',
#   'https://www.104.com.tw/job/?jobno=53wnz&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (242,
#   '設計指導(新媒體事業部/行動應用組)',
#   'https://www.104.com.tw/job/?jobno=4wgdq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (243,
#   'Staff Software Engineer - Full Stack (170173)',
#   'https://www.104.com.tw/job/?jobno=4rmq9&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (244,
#   'Principal Software Engineer C++',
#   'https://www.104.com.tw/job/?jobno=4s9jn&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (245,
#   '【核心功能服務】資訊管理-IT Support Specialist (DBA) - Senior / Manager level',
#   'https://www.104.com.tw/job/?jobno=4zo5k&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (246,
#   'IVS-Camera New Product FW Leader(中和)',
#   'https://www.104.com.tw/job/?jobno=4oku8&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (247,
#   'PMO專案組合管理師(知名銀行)-208KC',
#   'https://www.104.com.tw/job/?jobno=4pgyf&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (248,
#   'Software Engineering Product Manager',
#   'https://www.104.com.tw/job/?jobno=4ucv8&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (249,
#   'Senior C# Developer(台北)薪 5~10萬',
#   'https://www.104.com.tw/job/?jobno=4v03d&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (250,
#   '軟體研發-軟韌體研發專案經理',
#   'https://www.104.com.tw/job/?jobno=4mh00&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (251,
#   'BIOS工程師(SE100)',
#   'https://www.104.com.tw/job/?jobno=4ndwo&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (252,
#   'Mobile APP Developer',
#   'https://www.104.com.tw/job/?jobno=4mc54&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (253,
#   'Team Lead, Research and Development',
#   'https://www.104.com.tw/job/?jobno=4mt91&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (254,
#   '物聯網(Linux)韌體研發主管--電力能源事業單位',
#   'https://www.104.com.tw/job/?jobno=4il3o&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (255,
#   'T5R110-軟體工程師/主任工程師',
#   'https://www.104.com.tw/job/?jobno=4iz2t&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (256,
#   'Support Team Leader',
#   'https://www.104.com.tw/job/?jobno=4jc97&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (257,
#   '演算法開發經理',
#   'https://www.104.com.tw/job/?jobno=4jn6g&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (258,
#   '1040220 流程研發處 專案設計師',
#   'https://www.104.com.tw/job/?jobno=4prbh&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (259,
#   'Test develop Engineer/Manager',
#   'https://www.104.com.tw/job/?jobno=4q4mx&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (260,
#   '駐越資訊主管',
#   'https://www.104.com.tw/job/?jobno=4qlgz&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (261,
#   '【Information Technology】IT Project Manager (DBA) - 1700548',
#   'https://www.104.com.tw/job/?jobno=4qlte&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (262,
#   '應用系統設計師(票務通路系統課)-本公司提供高鐵通勤協助',
#   'https://www.104.com.tw/job/?jobno=4r3kz&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (263,
#   '行動通訊系統實體層(L1)軟體開發技術副理(新竹/台北)',
#   'https://www.104.com.tw/job/?jobno=4h14e&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (264,
#   'SoC Design  Manager/Staff Designer',
#   'https://www.104.com.tw/job/?jobno=4h75h&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (265,
#   'BIOS资深架构师',
#   'https://www.104.com.tw/job/?jobno=4hzp5&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (266,
#   '跨國集團誠徵手機多媒體研發工程師/主管(b92)',
#   'https://www.104.com.tw/job/?jobno=4iboy&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (267,
#   '多媒體架構師',
#   'https://www.104.com.tw/job/?jobno=4bmkt&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (268,
#   'Sr. Java Developer',
#   'https://www.104.com.tw/job/?jobno=4bxxn&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (269,
#   'Test Principal Engineer',
#   'https://www.104.com.tw/job/?jobno=4c5ux&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (270,
#   '資訊主管',
#   'https://www.104.com.tw/job/?jobno=4cjde&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (271,
#   'ERP 軟體工程師',
#   'https://www.104.com.tw/job/?jobno=4fqys&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (272,
#   '【BU1】 Linux程式開發主管/工程師(BSP/SI)',
#   'https://www.104.com.tw/job/?jobno=45pyp&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (273,
#   '研發類-軟體應用整合_處級主管(VSBG)',
#   'https://www.104.com.tw/job/?jobno=46d52&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (274,
#   'Team Lead Who Codes (Scrum Master)',
#   'https://www.104.com.tw/job/?jobno=47r08&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (275,
#   '系統整合工程師(Q12)',
#   'https://www.104.com.tw/job/?jobno=471cy&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (276,
#   '資訊戰略及專案推廣經理',
#   'https://www.104.com.tw/job/?jobno=49xo5&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (277,
#   'A1 駐外MES 系統開發經理',
#   'https://www.104.com.tw/job/?jobno=497ep&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (278,
#   '資訊處專案經理',
#   'https://www.104.com.tw/job/?jobno=4196c&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (279,
#   'Sr. Software Engineer (Linux/Android BSP) (DIGL-內湖)',
#   'https://www.104.com.tw/job/?jobno=3vbeb&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (280,
#   '系統架構師(Architect)',
#   'https://www.104.com.tw/job/?jobno=3wudj&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (281,
#   '【顧問部】經理/協理 (金融業資訊治理與績效)-319C',
#   'https://www.104.com.tw/job/?jobno=3lamq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (282,
#   '系統分析師(資訊管理處)',
#   'https://www.104.com.tw/job/?jobno=3la84&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (283,
#   '【顧問部】 經理/協理 (資訊治理與績效)-319C',
#   'https://www.104.com.tw/job/?jobno=2m2t5&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (284,
#   'TA4105 資深影像軟體工程師 (Camera Module)',
#   'https://www.104.com.tw/job/?jobno=2q4gn&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (285,
#   'Cloud System Consultant',
#   'https://www.104.com.tw/job/?jobno=2nmbf&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (286,
#   '通訊軟體研發主管&lt;新竹/土城&gt;',
#   'https://www.104.com.tw/job/?jobno=34jnx&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (287,
#   '韌體技術經理',
#   'https://www.104.com.tw/job/?jobno=388v1&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (288,
#   'A0408 NB軟體設計經理-BIOS(內湖)',
#   'https://www.104.com.tw/job/?jobno=lzwb&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (289,
#   '(資深)軟體主管',
#   'https://www.104.com.tw/job/?jobno=pr7t&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (290,
#   '【D720-05042】Smartphone/Tablet軟體主任工程師',
#   'https://www.104.com.tw/job/?jobno=5grv9&jobsource=n104bank1&hotjob_chr=',
#   9,
#   None),
#  (291,
#   '銀行(保險)業程式設計師(5/9日下班前截止收件)',
#   'https://www.104.com.tw/job/?jobno=5gs1c&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (292,
#   '資深軟體工程師',
#   'https://www.104.com.tw/job/?jobno=5g3wt&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (293,
#   'Systems Engineer',
#   'https://www.104.com.tw/job/?jobno=5ey8k&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (294,
#   'Network Engineer',
#   'https://www.104.com.tw/job/?jobno=5eya9&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (295,
#   '【DB50-4104】軟體主任工程師',
#   'https://www.104.com.tw/job/?jobno=5f6gj&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (296,
#   '資訊安全主管(K0600)',
#   'https://www.104.com.tw/job/?jobno=5f79z&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (297,
#   'Firmware Engineer',
#   'https://www.104.com.tw/job/?jobno=5cx50&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (298,
#   '架構師(Architect)',
#   'https://www.104.com.tw/job/?jobno=5eafe&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (299,
#   '410: Sr. Software Development Manager',
#   'https://www.104.com.tw/job/?jobno=5gjj4&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (300,
#   '1700483 - Reverse Logistics Manager for Asia (Location: Hsinchu)',
#   'https://www.104.com.tw/job/?jobno=5dzw6&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (301,
#   '1701095 -- AGS Logistics Onsite Manager (Location:Hsinchu)',
#   'https://www.104.com.tw/job/?jobno=5e034&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (302,
#   '【諮詢服務】Java高級軟體工程師',
#   'https://www.104.com.tw/job/?jobno=5e05m&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (303,
#   '軟體技術工程師(總公司)',
#   'https://www.104.com.tw/job/?jobno=5e1my&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (304,
#   'SAP系統工程師',
#   'https://www.104.com.tw/job/?jobno=5fqdw&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (305,
#   'MIS主管',
#   'https://www.104.com.tw/job/?jobno=5ccuh&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (306,
#   'IT專案經理',
#   'https://www.104.com.tw/job/?jobno=5cs3p&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (307,
#   'NO.C265220J001/網路管理資訊中心經理·MIS經理',
#   'https://www.104.com.tw/job/?jobno=5cm3f&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (308,
#   '資深Windows系統工程師 (派駐國外)',
#   'https://www.104.com.tw/job/?jobno=5eq2y&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (309,
#   'Oracle資料庫管理師 (派駐國外)',
#   'https://www.104.com.tw/job/?jobno=5eq3i&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (310,
#   '資深Windows系統工程師 (派駐國外)',
#   'https://www.104.com.tw/job/?jobno=5erh7&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (311,
#   'Oracle資料庫管理師 (派駐國外)',
#   'https://www.104.com.tw/job/?jobno=5erhz&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (312,
#   '資訊架構規劃師-208EL',
#   'https://www.104.com.tw/job/?jobno=59aqf&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (313,
#   '金控*區塊鏈工程師-208EL',
#   'https://www.104.com.tw/job/?jobno=59aqn&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (314,
#   '資訊工程師',
#   'https://www.104.com.tw/job/?jobno=5b9r5&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (315,
#   '(IT PM) IT Project Manager (供應鏈管理SCM)',
#   'https://www.104.com.tw/job/?jobno=5dc1g&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (316,
#   'Team Lead , Web',
#   'https://www.104.com.tw/job/?jobno=5dnku&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (317,
#   '【DB50-02141】Android軟體設計主任工程師',
#   'https://www.104.com.tw/job/?jobno=5c2ru&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (318,
#   'Manager, Application Engineering',
#   'https://www.104.com.tw/job/?jobno=5b0op&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (319,
#   '【資安所】資安所業發中心-研發工程師',
#   'https://www.104.com.tw/job/?jobno=58eq3&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (320,
#   '資訊組主任(總部)',
#   'https://www.104.com.tw/job/?jobno=58cre&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (321,
#   '【資安所】應用服務組-專案經理',
#   'https://www.104.com.tw/job/?jobno=55q3b&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (322,
#   '資訊安全管理顧問',
#   'https://www.104.com.tw/job/?jobno=561ng&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (323,
#   '資訊課長',
#   'https://www.104.com.tw/job/?jobno=52ojc&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (324,
#   '資企室儲備主管',
#   'https://www.104.com.tw/job/?jobno=54xdq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (325,
#   'A10-資訊部--資訊安全主管',
#   'https://www.104.com.tw/job/?jobno=554j5&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (326,
#   '資料庫管理師',
#   'https://www.104.com.tw/job/?jobno=56san&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (327,
#   '【中區】專案經理',
#   'https://www.104.com.tw/job/?jobno=56sur&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (328,
#   '【LAB】Sr. Software Engineer in Validation(中和)-TC16145',
#   'https://www.104.com.tw/job/?jobno=57beu&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (329,
#   'Sr. Software Engineer (Java skills)',
#   'https://www.104.com.tw/job/?jobno=56yg7&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (330,
#   'System Engineer (系統工程師)',
#   'https://www.104.com.tw/job/?jobno=4xa45&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (331,
#   'Solutions Architect/Engineer – Big Data',
#   'https://www.104.com.tw/job/?jobno=4xkl9&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (332,
#   '(IT PM) IT Project Manager (財會系統)',
#   'https://www.104.com.tw/job/?jobno=537di&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (333,
#   'Firmware Engineer',
#   'https://www.104.com.tw/job/?jobno=4r55y&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (334,
#   '【大數據所】資深軟體工程師(定期契約)',
#   'https://www.104.com.tw/job/?jobno=4rejn&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (335,
#   'MIS/軟體開發工程師',
#   'https://www.104.com.tw/job/?jobno=4z9zp&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (336,
#   'Mobility architect(BJ)',
#   'https://www.104.com.tw/job/?jobno=4ouu8&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (337,
#   '金融系統開發主管,經理/協理_208KC',
#   'https://www.104.com.tw/job/?jobno=4nrpw&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (338,
#   '【大數據所】巨量資料平台研發組長',
#   'https://www.104.com.tw/job/?jobno=4imhq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (339,
#   'Sr. RTOS BSP Developer',
#   'https://www.104.com.tw/job/?jobno=4i52c&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (340,
#   'Senior Software Engineer',
#   'https://www.104.com.tw/job/?jobno=4kh3v&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (341,
#   '5G 演算法 Senior System Engineer',
#   'https://www.104.com.tw/job/?jobno=4ktf8&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (342,
#   'Principle engineer, SSD HW platform firmware',
#   'https://www.104.com.tw/job/?jobno=4cq7v&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (343,
#   '資深IE工程師',
#   'https://www.104.com.tw/job/?jobno=444qq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (344,
#   'Java 系統架構師',
#   'https://www.104.com.tw/job/?jobno=47drp&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (345,
#   'T5R110-資深軟體主任工程師',
#   'https://www.104.com.tw/job/?jobno=482po&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (346,
#   'S/W 軟體研發部主管',
#   'https://www.104.com.tw/job/?jobno=3zhhz&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (347,
#   'Firmware design engineer',
#   'https://www.104.com.tw/job/?jobno=3zlmi&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (348,
#   '資深音頻工程師',
#   'https://www.104.com.tw/job/?jobno=5gco8&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (349,
#   '台灣彩券_資深網路管理工程師',
#   'https://www.104.com.tw/job/?jobno=5fdhj&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (350,
#   '車用軟體品質認證經理',
#   'https://www.104.com.tw/job/?jobno=5fgz4&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (351,
#   'D2R120-軟體資深主任工程師',
#   'https://www.104.com.tw/job/?jobno=5fjsd&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (352,
#   '系統分析師',
#   'https://www.104.com.tw/job/?jobno=5fc7h&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (353,
#   '網管人員',
#   'https://www.104.com.tw/job/?jobno=5fyl5&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (354,
#   'Team Lead - IT Service Support',
#   'https://www.104.com.tw/job/?jobno=5eyo0&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (355,
#   '系統分析師 (Systems Analyst)',
#   'https://www.104.com.tw/job/?jobno=5eyoy&jobsource=n104bank1&hotjob_chr=',
#   11,
#   None),
#  (356,
#   'ASP.NET 應用程式架構師 (ASP.NET Application Architect)',
#   'https://www.104.com.tw/job/?jobno=5f5af&jobsource=n104bank1&hotjob_chr=',
#   9,
#   None),
#  (357,
#   'I3711 訂單管理資訊部 副理',
#   'https://www.104.com.tw/job/?jobno=5f5cq&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (358,
#   '課長/副理',
#   'https://www.104.com.tw/job/?jobno=5f7p8&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (359,
#   'IT Software Engineer- - EAD Business Solution Delivery',
#   'https://www.104.com.tw/job/?jobno=5d5fj&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (360,
#   'IoT 資深軟體研發工程師 (通訊協定應用與實現)',
#   'https://www.104.com.tw/job/?jobno=5e89n&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (361,
#   'Senior Product Test Engineer',
#   'https://www.104.com.tw/job/?jobno=5eb5o&jobsource=n104bank1&hotjob_chr=',
#   8,
#   None),
#  (362,
#   'Sales and Systems Engineer (English Native Speaker living in US)',
#   'https://www.104.com.tw/job/?jobno=5edi7&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (363,
#   '系統主任工程師(中壢)',
#   'https://www.104.com.tw/job/?jobno=5eeq7&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (364,
#   'HIL模擬應用主任工程師(中壢)',
#   'https://www.104.com.tw/job/?jobno=5eerr&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (365,
#   '1002850 System Integration Technical Lead',
#   'https://www.104.com.tw/job/?jobno=5gjwh&jobsource=n104bank1&hotjob_chr=',
#   7,
#   None),
#  (366,
#   '1002849 Software Program Manager',
#   'https://www.104.com.tw/job/?jobno=5gjwm&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (367,
#   'RFID系統應用工程師',
#   'https://www.104.com.tw/job/?jobno=5gmi1&jobsource=n104bank1&hotjob_chr=',
#   9,
#   None),
#  (368,
#   '資深EDA軟體工程師',
#   'https://www.104.com.tw/job/?jobno=5duty&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (369,
#   '[RD] 資深PHP工程師',
#   'https://www.104.com.tw/job/?jobno=5e07s&jobsource=n104bank1&hotjob_chr=',
#   6,
#   None),
#  (370,
#   '【SW】相機/鏡頭演算法開發專才(土城)',
#   'https://www.104.com.tw/job/?jobno=5e5io&jobsource=n104bank1&hotjob_chr=',
#   5,
#   None),
#  (371,
#   'IS Manager (IT Manager)',
#   'https://www.104.com.tw/job/?jobno=5e66p&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (372,
#   'Head of Infrastructure, AIG Taiwan',
#   'https://www.104.com.tw/job/?jobno=5e6re&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (373,
#   'Business Analyst',
#   'https://www.104.com.tw/job/?jobno=5fmzs&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (374,
#   'Business Analyst',
#   'https://www.104.com.tw/job/?jobno=5fn00&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (375,
#   '研發類-影像處理演算法Leader(VSBG)',
#   'https://www.104.com.tw/job/?jobno=5fobb&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (376,
#   'IT Implementation & Service Specialist',
#   'https://www.104.com.tw/job/?jobno=5citf&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (377,
#   'Software Development Engineer - PDK',
#   'https://www.104.com.tw/job/?jobno=5en0p&jobsource=n104bank1&hotjob_chr=',
#   2,
#   None),
#  (378,
#   'Internet/App 網頁工程師',
#   'https://www.104.com.tw/job/?jobno=5es7s&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (379,
#   '技術部經理(台北)',
#   'https://www.104.com.tw/job/?jobno=5985e&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (380,
#   'MIS',
#   'https://www.104.com.tw/job/?jobno=599si&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (381,
#   'IT Business Intelligence Analyst, EAD Business Solutions',
#   'https://www.104.com.tw/job/?jobno=5b70z&jobsource=n104bank1&hotjob_chr=',
#   4,
#   None),
#  (382,
#   'LTD Software Teamleader-PCB (Taoyuan)',
#   'https://www.104.com.tw/job/?jobno=5bdf4&jobsource=n104bank1&hotjob_chr=',
#   3,
#   None),
#  (383,
#   'Staff Tools Software Engineer',
# ...
#  (18745,
#   '【設計所】字體品管專員',
#   'https://www.104.com.tw/job/?jobno=5fcou&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18746,
#   'Content Research Officer內容調研主任',
#   'https://www.104.com.tw/job/?jobno=5efrg&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18747,
#   'PANDORA JEWELRY - CRM 專員',
#   'https://www.104.com.tw/job/?jobno=5gj3i&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18748,
#   '營運管理分析專員/資料分析員',
#   'https://www.104.com.tw/job/?jobno=3dbzg&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18749,
#   '台中-資料庫工程師',
#   'https://www.104.com.tw/job/?jobno=56z42&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18750,
#   '長期工讀生（行動媒體部-視頻營運中心）',
#   'https://www.104.com.tw/job/?jobno=4kklf&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18751,
#   '警務助理管理師-總管理處(S)',
#   'https://www.104.com.tw/job/?jobno=51nb6&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18752,
#   '資訊室  資料庫管理人員',
#   'https://www.104.com.tw/job/?jobno=5ajdi&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18753,
#   'ERP-IT助理',
#   'https://www.104.com.tw/job/?jobno=5cz28&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18754,
#   'DBA (MySQL資料庫管理人員)',
#   'https://www.104.com.tw/job/?jobno=4i70x&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18755,
#   '數據分析專員',
#   'https://www.104.com.tw/job/?jobno=5f00g&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18756,
#   '倉管行政助理人員(桃園市八德區)',
#   'https://www.104.com.tw/job/?jobno=4g6um&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18757,
#   'WIH170310-資料分析工程師',
#   'https://www.104.com.tw/job/?jobno=30il5&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18758,
#   '營運調研分析師 Research Analyst',
#   'https://www.104.com.tw/job/?jobno=4fk29&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18759,
#   '【SS2 OX】DBA 資料庫管理師',
#   'https://www.104.com.tw/job/?jobno=4rb5v&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18760,
#   '資料庫管理師',
#   'https://www.104.com.tw/job/?jobno=4d272&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18761,
#   '軟體研發工程師',
#   'https://www.104.com.tw/job/?jobno=5blh2&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18762,
#   'ITP_656 MS SQL DBA',
#   'https://www.104.com.tw/job/?jobno=551js&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18763,
#   '資料庫管理師',
#   'https://www.104.com.tw/job/?jobno=47nlp&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18764,
#   '資訊文管人員',
#   'https://www.104.com.tw/job/?jobno=5at73&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18765,
#   'SAP應用管理師(總公司)',
#   'https://www.104.com.tw/job/?jobno=59z1z&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18766,
#   '總公司-資訊專員(DBA)',
#   'https://www.104.com.tw/job/?jobno=5c3qt&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18767,
#   '營運數據分析工程師',
#   'https://www.104.com.tw/job/?jobno=5fnm8&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18768,
#   '【Contractor】Oracle DBA-105ZL',
#   'https://www.104.com.tw/job/?jobno=58m60&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18769,
#   '人資專員',
#   'https://www.104.com.tw/job/?jobno=4i0u5&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18770,
#   '#170025498 - CIB Operations - Documentation Management Ops - Specialist – '
#   'Contract',
#   'https://www.104.com.tw/job/?jobno=4ylto&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18771,
#   '【中區處】軟體平台工程師',
#   'https://www.104.com.tw/job/?jobno=4twgw&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18772,
#   '資料庫應用開發工程師',
#   'https://www.104.com.tw/job/?jobno=3uecu&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18773,
#   '資料中心規劃經理-台北',
#   'https://www.104.com.tw/job/?jobno=5buij&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18774,
#   '結核病中心 研究助理',
#   'https://www.104.com.tw/job/?jobno=3m46t&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18775,
#   '資料庫管理工程師(DBA)(派駐海外)',
#   'https://www.104.com.tw/job/?jobno=511s3&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18776,
#   '資深oracle DBA',
#   'https://www.104.com.tw/job/?jobno=3t4oh&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18777,
#   '資深資料庫管理師(SQL Server)',
#   'https://www.104.com.tw/job/?jobno=5cpnt&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18778,
#   '資管(中科廠)',
#   'https://www.104.com.tw/job/?jobno=5dbjc&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18779,
#   'CIM資訊工程師(嘉義廠/嘉義大埔美)',
#   'https://www.104.com.tw/job/?jobno=56yw4&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18780,
#   'DBA資料庫管理工程師',
#   'https://www.104.com.tw/job/?jobno=59adj&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18781,
#   'ML-【信義】純軟公司徵 數據分析Data Analyst, 年薪$60~90萬',
#   'https://www.104.com.tw/job/?jobno=542dg&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18782,
#   'SAP Basis 顧問',
#   'https://www.104.com.tw/job/?jobno=3ct4i&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18783,
#   '行銷數據分析師',
#   'https://www.104.com.tw/job/?jobno=5br7o&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18784,
#   '理賠系統規劃專員(保險核心系統)',
#   'https://www.104.com.tw/job/?jobno=4gsoy&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18785,
#   '企業夥伴(BP)系統規劃專員(保險核心系統)',
#   'https://www.104.com.tw/job/?jobno=5cyjj&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18786,
#   '核保系統規劃專員(保險核心系統)',
#   'https://www.104.com.tw/job/?jobno=556xt&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18787,
#   '資料庫開發人員',
#   'https://www.104.com.tw/job/?jobno=44d7a&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18788,
#   '【派駐客戶端/年薪70萬~80萬】資料庫管理工程師Database Administrator Engineer-105ZL',
#   'https://www.104.com.tw/job/?jobno=5g09n&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18789,
#   '【派駐客戶端/年薪70萬~80萬】資料庫管理工程師Database Administrator Engineer-105ZL',
#   'https://www.104.com.tw/job/?jobno=5b5au&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18790,
#   '計畫僱用助理(統計調查)',
#   'https://www.104.com.tw/job/?jobno=4duuq&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18791,
#   '資料庫管理工程師',
#   'https://www.104.com.tw/job/?jobno=3noe3&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18792,
#   '資料庫開發工程師',
#   'https://www.104.com.tw/job/?jobno=47hs1&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18793,
#   '資料庫管理工程師',
#   'https://www.104.com.tw/job/?jobno=57m8u&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18794,
#   '資料庫管理人員',
#   'https://www.104.com.tw/job/?jobno=4nt88&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18795,
#   'SQL資料庫工程師',
#   'https://www.104.com.tw/job/?jobno=5et0a&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18796,
#   '1A80- 資訊室 資料庫管理師',
#   'https://www.104.com.tw/job/?jobno=4cxyj&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18797,
#   '廠務行政人員',
#   'https://www.104.com.tw/job/?jobno=39vxb&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18798,
#   '【實習】Web Developer Intern - 學生實習',
#   'https://www.104.com.tw/job/?jobno=5fu7d&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18799,
#   '【實習】 Data Engineer Intern - 學生實習',
#   'https://www.104.com.tw/job/?jobno=5fu8i&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18800,
#   '資料庫數據分析工程師',
#   'https://www.104.com.tw/job/?jobno=55uet&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18801,
#   '資訊助理(工讀生/土城場區)',
#   'https://www.104.com.tw/job/?jobno=423qd&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18802,
#   '營收管理專員 Revenue Coordinator',
#   'https://www.104.com.tw/job/?jobno=5cn0p&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18803,
#   '資訊專員',
#   'https://www.104.com.tw/job/?jobno=5fsv2&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18804,
#   '資料探勘工程師',
#   'https://www.104.com.tw/job/?jobno=4u9yz&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18805,
#   '資料系統分析師/物流儲備幹部 (約聘)',
#   'https://www.104.com.tw/job/?jobno=4sxin&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18806,
#   '資深分析/分析，顧客智識與消費行為研究部(上海)',
#   'https://www.104.com.tw/job/?jobno=3aobs&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18807,
#   '資深分析/分析，顧客智識與消費行為研究部(台北)',
#   'https://www.104.com.tw/job/?jobno=42eae&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18808,
#   '0012A 台北總公司 全職 市場分析專員/助理 (合約管理)',
#   'https://www.104.com.tw/job/?jobno=5fgd1&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18809,
#   '繪圖人員 (台中) /正職',
#   'https://www.104.com.tw/job/?jobno=5accl&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18810,
#   '資產管理人員',
#   'https://www.104.com.tw/job/?jobno=4aycy&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18811,
#   '資料庫管理員(金石堂網路書店)',
#   'https://www.104.com.tw/job/?jobno=33bdq&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18812,
#   '營運調研分析師 Research Analyst',
#   'https://www.104.com.tw/job/?jobno=5erke&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18813,
#   '活動網路總監',
#   'https://www.104.com.tw/job/?jobno=4qj53&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18814,
#   '網路業務專員',
#   'https://www.104.com.tw/job/?jobno=4qj69&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18815,
#   '資深資料庫管理師',
#   'https://www.104.com.tw/job/?jobno=5acwn&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18816,
#   '【派駐客戶端/年薪0.7M-0.8M】資料庫管理工程師Database Administrator Engineer-105ZL',
#   'https://www.104.com.tw/job/?jobno=5f0g7&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18817,
#   '新光人壽-(資深)數據分析師/數據分析襄理(Data Analyst)',
#   'https://www.104.com.tw/job/?jobno=2z4hi&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18818,
#   '資料庫管理師(流通業)',
#   'https://www.104.com.tw/job/?jobno=565zs&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18819,
#   '[幸福企業召募]Oracle資料庫技術顧問',
#   'https://www.104.com.tw/job/?jobno=5bpf9&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18820,
#   'SM700 智慧型裝置事業群-主任/高級資料庫管理工程師(DBA)',
#   'https://www.104.com.tw/job/?jobno=3z0uk&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18821,
#   '資料庫管理師',
#   'https://www.104.com.tw/job/?jobno=4a0e6&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18822,
#   'ETL資料工程師',
#   'https://www.104.com.tw/job/?jobno=5e9ei&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18823,
#   'SQL資料庫工程師',
#   'https://www.104.com.tw/job/?jobno=5e6v1&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18824,
#   'DBA工程師',
#   'https://www.104.com.tw/job/?jobno=55w99&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18825,
#   '跨境電子商務行銷企劃',
#   'https://www.104.com.tw/job/?jobno=4bios&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18826,
#   '電子商務行銷企劃專員',
#   'https://www.104.com.tw/job/?jobno=405b5&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18827,
#   '網路行銷企劃專員',
#   'https://www.104.com.tw/job/?jobno=2pslg&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18828,
#   '701: DBA (Data Center Service Team, DCS)',
#   'https://www.104.com.tw/job/?jobno=518cn&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18829,
#   'A+種子實習_Data Matrix 與 PI thin Client 的 Auto deploy',
#   'https://www.104.com.tw/job/?jobno=5fdn3&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18830,
#   '圖文資料庫數位出版編輯',
#   'https://www.104.com.tw/job/?jobno=5c4sq&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18831,
#   '系統工程師(資料庫管理)',
#   'https://www.104.com.tw/job/?jobno=2d5io&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18832,
#   'IH-數據資料工程師',
#   'https://www.104.com.tw/job/?jobno=4yi7e&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18833,
#   '資料庫工程師',
#   'https://www.104.com.tw/job/?jobno=5g4yi&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18834,
#   '資料庫管理師 DBA',
#   'https://www.104.com.tw/job/?jobno=4spsq&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18835,
#   '資訊管理師',
#   'https://www.104.com.tw/job/?jobno=4vnk9&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18836,
#   '資料庫系統設計師 (網路事業部)',
#   'https://www.104.com.tw/job/?jobno=4iczo&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18837,
#   '運維架構師(歡迎到菲律賓展開精采的海外人生)',
#   'https://www.104.com.tw/job/?jobno=5931u&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18838,
#   '【企業管理諮詢服務】MS SQL Technical Consultant - Senior Level',
#   'https://www.104.com.tw/job/?jobno=588o4&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18839,
#   '財會行政助理',
#   'https://www.104.com.tw/job/?jobno=457tu&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18840,
#   '(C)分析高級工程師(土城)',
#   'https://www.104.com.tw/job/?jobno=4bw43&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18841,
#   '遊戲系統工程師',
#   'https://www.104.com.tw/job/?jobno=4ydzk&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18842,
#   'MSSQL DBA',
#   'https://www.104.com.tw/job/?jobno=59a7s&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18843,
#   'Oracle DBA',
#   'https://www.104.com.tw/job/?jobno=3jhv4&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18844,
#   '【顧問部】風險管理系統分析師 (財務風險管理 資料模型設計)-316',
#   'https://www.104.com.tw/job/?jobno=4j0mu&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18845,
#   '【顧問部】顧問師/高級顧問師/副理/經理 (電腦審計)-319A',
#   'https://www.104.com.tw/job/?jobno=33kq6&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18846,
#   '資訊助理工程師',
#   'https://www.104.com.tw/job/?jobno=5fmo8&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18847,
#   '市場風險控管/資訊規劃人員',
#   'https://www.104.com.tw/job/?jobno=59nhh&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18848,
#   'DBA資料庫管理工程師(上海)_5981',
#   'https://www.104.com.tw/job/?jobno=54vrz&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18849,
#   '資料庫工程師',
#   'https://www.104.com.tw/job/?jobno=5dm4v&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18850,
#   'Database administrator(DBA)',
#   'https://www.104.com.tw/job/?jobno=48fyp&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18851,
#   'DBA(MS SQL資料庫管理工程師)',
#   'https://www.104.com.tw/job/?jobno=49w6z&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18852,
#   '【健檢中心】行政人員',
#   'https://www.104.com.tw/job/?jobno=535v1&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18853,
#   'Analytic Data Scientist',
#   'https://www.104.com.tw/job/?jobno=4jyj4&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18854,
#   'Oracle DBA',
#   'https://www.104.com.tw/job/?jobno=4qbga&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18855,
#   '04_績效管理人員(台北市內湖區)',
#   'https://www.104.com.tw/job/?jobno=5b9br&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18856,
#   'ERP 財務專員',
#   'https://www.104.com.tw/job/?jobno=4ifyo&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18857,
#   '會員行銷企劃',
#   'https://www.104.com.tw/job/?jobno=5a4y7&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18858,
#   '旺旺中時媒體集團_(CTI) 助理資管師',
#   'https://www.104.com.tw/job/?jobno=5cis6&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18859,
#   '旺旺中時媒體集團_(CTI) 資管師',
#   'https://www.104.com.tw/job/?jobno=5220v&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18860,
#   '【電子商務部】資料庫管理師',
#   'https://www.104.com.tw/job/?jobno=3kbx6&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18861,
#   'MIS資料庫管理員-管理部(台北新店)',
#   'https://www.104.com.tw/job/?jobno=5dshg&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18862,
#   'Data Scientist',
#   'https://www.104.com.tw/job/?jobno=4jao3&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18863,
#   '新幹班-G01-系統數據工程師(大陸-龍華)',
#   'https://www.104.com.tw/job/?jobno=4tc9g&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18864,
#   '資料庫運用暨分析人員',
#   'https://www.104.com.tw/job/?jobno=3bz4w&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18865,
#   '客群資料分析人員',
#   'https://www.104.com.tw/job/?jobno=2iwja&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18866,
#   '資料庫管理師(DBA)',
#   'https://www.104.com.tw/job/?jobno=1081u&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18867,
#   '【公司內部】急缺 系統開發工程師(北屯區)#Power',
#   'https://www.104.com.tw/job/?jobno=4fgtf&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18868,
#   '(Information Technology) Data Engineer - J00970',
#   'https://www.104.com.tw/job/?jobno=46zg4&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18869,
#   '新光銀行-系統分析師-資料倉儲管理(商業智慧科)',
#   'https://www.104.com.tw/job/?jobno=4tei6&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18870,
#   '平台架構工程師/主管',
#   'https://www.104.com.tw/job/?jobno=539wk&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18871,
#   '大數據系統架構師',
#   'https://www.104.com.tw/job/?jobno=4rdku&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18872,
#   'Oracle Database consultant',
#   'https://www.104.com.tw/job/?jobno=32a58&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18873,
#   'Oracle DBA',
#   'https://www.104.com.tw/job/?jobno=3lhq0&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None),
#  (18874,
#   '系統開發工程師',
#   'https://www.104.com.tw/job/?jobno=4mlxb&jobsource=n104bank1&hotjob_chr=',
#   1,
#   None)]

# %%
# Query maximun times
with sqlite3.connect('job.sqlite') as conn:
    c = conn.cursor()
#     pprint.pprint(list(c.execute('select * from job104 where times > 1')))
    pprint.pprint(list(c.execute('select count(times), sum(times) from job104 where times > 1')))
# Out:
# [(15101, 64191)]

# %%
# ranking function
# ranking = sorted(dict.items(),key=lambda d:d[1],reverse = True) #用出現次數排順序
